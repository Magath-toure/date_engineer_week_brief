# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# importation des données Olist

Customers = pd.read_csv('data/customers_dataset.csv')

# Geolocation = pd.read_csv('data/geolocation_dataset.csv')

Order_items = pd.read_csv('data/order_items_dataset.csv')


Order_payments= pd.read_csv('data/order_payments_dataset.csv')


Order_review_clean = pd.read_csv('data/order_review_dataset_clean.csv')

Orders = pd.read_csv('data/orders_dataset.csv')

Product_category = pd.read_csv('data/product_category_name_translation.csv')

Product = pd.read_csv('data/products_dataset.csv')

#Sellers = pd.read_csv('data/sellers_dataset.csv')

State_name = pd.read_csv('data/state_name.csv')

# %%
# Nombre de clients par état dans la table customers
nbe_clients_par_etat =  Customers.groupby('customer_state')['customer_id'].count()

nbe_clients_par_etat

# %%
# Creation du grapique du nombre de client par etat

plt.figure(figsize=(14, 6))
plt.bar(df.index, df['customer_id'] )
plt.xlabel('Etat')
plt.ylabel('Nombre de client')
plt.title('Nombre de client par etat')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# analyse univariée: histogrammes pour le svaleurs numeriques

plt.hist(['customer_state'], color='skyblue', edgecolor='black')
plt.xlabel('valeures numeriques')
plt.ylabel('frequence')
plt.title('Histogramme de la colonne numerique')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Barplot pour les gatégories
plt.figure(figsize=(14, 6))
Product['product_category_name'].value_counts().plot(kind='bar', color='red')
plt.xlabel('categorie')
plt.ylabel('frequence')
plt.title('Barplot des categories')
plt.show()

# %%
# Barplot pour les gatégories
plt.figure(figsize=(14, 6))
Product['product_category_name'].value_counts().plot(kind='bar', color='red')



plt.xlabel('categorie')
plt.ylabel('frequence')
plt.title('Barplot des categories')
plt.show()

# %%
df = pd.merge(Product, Product_category, on='product_category_name', how='inner')
df
# Out:
#                              product_id      product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                 perfumaria
# 1      6a2fb4dd53d2cdb88e0432f1284a004c                 perfumaria
# 2      0d009643171aee696f4733340bc2fdd0                 perfumaria
# 3      b1eae565a61935e0011ee7682fef9dc9                 perfumaria
# 4      8da90b37f0fb171b4877c124f965b1f6                 perfumaria
# ...                                 ...                        ...
# 32323  13b25797ad1e6d6c7cd3cbeb35f8ee7a  moveis_colchao_e_estofado
# 32324  dc36a7859b743d8610a2bbbaea26ece9  moveis_colchao_e_estofado
# 32325  107fde0930956120d1e13dd1062fbb46  moveis_colchao_e_estofado
# 32326  726b4e18f00255e2e63491bcba3f60b8  moveis_colchao_e_estofado
# 32327  1dceebcc5f23c02ea23e16d5bedca000          cds_dvds_musicais
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# ...

# %%
plt.figure(figsize=(14, 6))
df['product_category_name_english'].value_counts().plot(kind='bar', color='red')
plt.xlabel('categorie')
plt.ylabel('frequence')
plt.title('Barplot des categories')
plt.show()

# %%
# analyse bivariéé: scartter plot
plt.scatter(df['product_id'], ['product_category_name'], 
            c='orange', alpha=0.5, marker='+')
plt.xlabel('commande')
plt.ylabel('elements de commande')
plt.title('visualisation scatter')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 index.df
#
# NameError: name 'index' is not defined

# %%
# Out:
# Index(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS',
#        'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC',
#        'SE', 'SP', 'TO'],
#       dtype='object', name='customer_state')

# %%
# Out:
#                 customer_id
# customer_state
# AC                       81
# AL                      413
# AM                      148
# AP                       68
# BA                     3380

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Nombres de commande par etat
# ----> 2 nbr_commande_par_etat = orders.groupby('order_items')['order_id'].count()
#       3 nbr_commande_par_etat
#
# NameError: name 'orders' is not defined
